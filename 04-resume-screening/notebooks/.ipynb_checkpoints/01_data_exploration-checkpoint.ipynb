# %% [markdown]
# # Resume & Job Data Exploration
# ## Phase 2: Data Exploration & Understanding
#
# This notebook explores our generated resume and job description datasets to understand:
# - Data quality and structure
# - Feature distributions
# - Potential matching patterns

# %%
# Import required libraries for data analysis and visualization
import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
import numpy as np

# Set visualization style
plt.style.use('default')
sns.set_palette("husl")

# %% [markdown]
# ## 1. Load and Inspect Data

# %%
# Load resume data from JSON file
with open('../data/synthetic_resumes/resumes.json', 'r') as f:
    resumes_data = json.load(f)

# Load job descriptions from JSON file  
with open('../data/jobs.json', 'r') as f:
    jobs_data = json.load(f)

print(f"Loaded {len(resumes_data)} resumes and {len(jobs_data)} job descriptions")
# Out:
# Loaded 10 resumes and 25 job descriptions

# %%
# Convert JSON data to pandas DataFrames for easier analysis
resumes_df = pd.DataFrame(resumes_data)
jobs_df = pd.DataFrame(jobs_data)

print("Resume DataFrame Info:")
print(resumes_df.info())
print("\nFirst 3 resumes:")
print(resumes_df.head(3))
# Out:
# Resume DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              10 non-null     object
#  1   role_category     10 non-null     object
#  2   skills            10 non-null     object
#  3   experience_years  10 non-null     int64
# dtypes: int64(1), object(3)
# memory usage: 452.0+ bytes
# None
#
# First 3 resumes:
#             name      role_category                skills  experience_years
# 0     John Smith    DevOps Engineer   [Docker, AWS, Java]                10
# 1  Sarah Johnson  Software Engineer  [Python, React, SQL]                 8
# 2  Sarah Johnson  Software Engineer     [SQL, React, AWS]                 7

# %%
print("Job DataFrame Info:")
print(jobs_df.info())
print("\nFirst 3 jobs:")
print(jobs_df.head(3))
# Out:
# Job DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   title            25 non-null     object
#  1   required_skills  25 non-null     object
#  2   min_experience   25 non-null     int64
#  3   max_experience   25 non-null     int64
#  4   company          25 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 1.1+ KB
# None
#
# First 3 jobs:
#                title               required_skills  min_experience  \
# 0     Data Scientist  [Python, Docker, React, SQL]               2
# 1  Software Engineer      [SQL, AWS, Java, Docker]               4
# 2  Software Engineer    [Java, React, AWS, Python]               5
#
#    max_experience     company
# 0               9  DevCompany
# 1               5    DataSoft
# 2               5  DevCompany

# %% [markdown]
# ## 2. Basic Statistics

# %%
# Analyze resume experience distribution
print("=== RESUME STATISTICS ===")
print(f"Total resumes: {len(resumes_df)}")
print(f"Unique names: {resumes_df['name'].nunique()}")
print(f"Experience years - Min: {resumes_df['experience_years'].min()}, Max: {resumes_df['experience_years'].max()}")
print(f"Average experience: {resumes_df['experience_years'].mean():.1f} years")

# Count role categories in resumes
print("\nRole distribution:")
print(resumes_df['role_category'].value_counts())
# Out:
# === RESUME STATISTICS ===
# Total resumes: 10
# Unique names: 4
# Experience years - Min: 1, Max: 10
# Average experience: 5.1 years
#
# Role distribution:
# role_category
# DevOps Engineer      6
# Software Engineer    4
# Name: count, dtype: int64

# %%
# Analyze job posting statistics
print("=== JOB STATISTICS ===")
print(f"Total jobs: {len(jobs_df)}")
print(f"Unique companies: {jobs_df['company'].nunique()}")
print(f"Experience range - Min: {jobs_df['min_experience'].min()}-{jobs_df['max_experience'].min()}, Max: {jobs_df['min_experience'].max()}-{jobs_df['max_experience'].max()}")

# Count job titles
print("\nJob title distribution:")
print(jobs_df['title'].value_counts())
# Out:
# === JOB STATISTICS ===
# Total jobs: 25
# Unique companies: 4
# Experience range - Min: 1-5, Max: 5-10
#
# Job title distribution:
# title
# Software Engineer    13
# Data Scientist        7
# DevOps Engineer       5
# Name: count, dtype: int64

# %% [markdown]
# ## 3. Skills Analysis

# %%
# Extract and count all skills from resumes
# Flatten the list of skills from all resumes
all_resume_skills = []
for skills_list in resumes_df['skills']:
    all_resume_skills.extend(skills_list)

# Count frequency of each skill in resumes
resume_skill_counts = Counter(all_resume_skills)
print("Top 10 skills in resumes:")
for skill, count in resume_skill_counts.most_common(10):
    print(f"{skill}: {count}")
# Out:
# Top 10 skills in resumes:
# AWS: 7
# SQL: 7
# Python: 6
# React: 4
# Docker: 3
# Java: 3

# %%
# Extract and count all skills from job descriptions
all_job_skills = []
for skills_list in jobs_df['required_skills']:
    all_job_skills.extend(skills_list)

# Count frequency of each skill in job postings
job_skill_counts = Counter(all_job_skills)
print("Top 10 skills in job descriptions:")
for skill, count in job_skill_counts.most_common(10):
    print(f"{skill}: {count}")
# Out:
# Top 10 skills in job descriptions:
# AWS: 18
# SQL: 17
# Python: 16
# React: 16
# Java: 16
# Docker: 14

# %% [markdown]
# ## 4. Data Visualizations

# %%
# Create subplots for experience distribution comparison
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))

# Plot resume experience distribution
ax1.hist(resumes_df['experience_years'], bins=10, alpha=0.7, color='skyblue', edgecolor='black')
ax1.set_title('Resume Experience Distribution')
ax1.set_xlabel('Years of Experience')
ax1.set_ylabel('Count')
ax1.grid(True, alpha=0.3)

# Plot job experience requirements (using min_experience as proxy)
ax2.hist(jobs_df['min_experience'], bins=10, alpha=0.7, color='lightcoral', edgecolor='black')
ax2.set_title('Job Minimum Experience Requirements')
ax2.set_xlabel('Minimum Years Required')
ax2.set_ylabel('Count')
ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %%
# Create skill comparison visualization
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 10))

# Top resume skills bar chart
top_resume_skills = dict(resume_skill_counts.most_common(8))
ax1.bar(top_resume_skills.keys(), top_resume_skills.values(), color='lightblue', alpha=0.8)
ax1.set_title('Most Common Skills in Resumes')
ax1.set_ylabel('Frequency')
ax1.tick_params(axis='x', rotation=45)

# Top job skills bar chart
top_job_skills = dict(job_skill_counts.most_common(8))
ax2.bar(top_job_skills.keys(), top_job_skills.values(), color='lightcoral', alpha=0.8)
ax2.set_title('Most Requested Skills in Job Descriptions')
ax2.set_ylabel('Frequency')
ax2.tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5. Data Quality Assessment

# %%
from IPython.display import display, Markdown

# Display bold and larger headings using Markdown
display(Markdown("### **DATA QUALITY CHECK**"))

print("\nResume data missing values:")
print(resumes_df.isnull().sum())

print("\nJob data missing values:")
print(jobs_df.isnull().sum())

# Check for empty skill lists
empty_resume_skills = sum(1 for skills in resumes_df['skills'] if len(skills) == 0)
empty_job_skills = sum(1 for skills in jobs_df['required_skills'] if len(skills) == 0)

print(f"\nResumes with no skills: {empty_resume_skills}")
print(f"Jobs with no required skills: {empty_job_skills}")
# Out:
# ### **DATA QUALITY CHECK**
# Resume data missing values:
# name                0
# role_category       0
# skills              0
# experience_years    0
# dtype: int64
#
# Job data missing values:
# title              0
# required_skills    0
# min_experience     0
# max_experience     0
# company            0
# dtype: int64
#
# Resumes with no skills: 0
# Jobs with no required skills: 0

# %%
from IPython.display import display, Markdown
import numpy as np  # Assuming you're using numpy

# Calculate average number of skills per resume/job
resume_skill_lengths = [len(skills) for skills in resumes_df['skills']]
job_skill_lengths = [len(skills) for skills in jobs_df['required_skills']]

# Display heading
display(Markdown("### **SKILL STATISTICS**"))

print(f"Average skills per resume: {np.mean(resume_skill_lengths):.1f}")
print(f"Average required skills per job: {np.mean(job_skill_lengths):.1f}")

print(f"\nSkill count ranges:")
print(f"Resumes: {min(resume_skill_lengths)}-{max(resume_skill_lengths)} skills")
print(f"Jobs: {min(job_skill_lengths)}-{max(job_skill_lengths)} skills")
# Out:
# ### **SKILL STATISTICS**
# Average skills per resume: 3.0
# Average required skills per job: 3.9
#
# Skill count ranges:
# Resumes: 3-3 skills
# Jobs: 3-5 skills

# %% [markdown]
# ## 6. Initial Matching Analysis

# %%
from IPython.display import display, Markdown

# Heading
display(Markdown("### **SAMPLE MATCHING ANALYSIS**"))

# Simple skill overlap analysis for potential matching
def calculate_skill_overlap(resume_skills, job_skills):
    """Calculate percentage of job skills that candidate has"""
    resume_set = set(resume_skills)
    job_set = set(job_skills)
    overlap = len(resume_set.intersection(job_set))
    return overlap / len(job_set) if job_set else 0

# Test with first few resumes and jobs
for i in range(min(3, len(resumes_df))):
    resume = resumes_df.iloc[i]
    print(f"\nResume {i+1}: {resume['name']} ({resume['role_category']}, {resume['experience_years']} years)")
    print(f"Skills: {resume['skills']}")
    
    for j in range(min(2, len(jobs_df))):
        job = jobs_df.iloc[j]
        overlap = calculate_skill_overlap(resume['skills'], job['required_skills'])
        print(f"  Match with {job['title']}: {overlap:.1%} skill overlap")
# Out:
# ### **SAMPLE MATCHING ANALYSIS**
# Resume 1: John Smith (DevOps Engineer, 10 years)
# Skills: ['Docker', 'AWS', 'Java']
#   Match with Data Scientist: 25.0% skill overlap
#   Match with Software Engineer: 75.0% skill overlap
#
# Resume 2: Sarah Johnson (Software Engineer, 8 years)
# Skills: ['Python', 'React', 'SQL']
#   Match with Data Scientist: 75.0% skill overlap
#   Match with Software Engineer: 25.0% skill overlap
#
# Resume 3: Sarah Johnson (Software Engineer, 7 years)
# Skills: ['SQL', 'React', 'AWS']
#   Match with Data Scientist: 50.0% skill overlap
#   Match with Software Engineer: 50.0% skill overlap

# %% [markdown]
# ## Summary & Next Steps
#
# Based on this exploration:
# 1. **Data Quality**: Check if data looks clean and complete
# 2. **Feature Distribution**: Understand skill and experience patterns
# 3. **Matching Potential**: See initial overlap between resumes and jobs
#
# **Next Phase**: Move to data preprocessing and feature engineering

# %%
## 7. View Preprocessed Data

# Load processed data into pandas DataFrames
processed_resumes_df = pd.read_csv('../data/processed/resumes_processed.csv')
processed_jobs_df = pd.read_csv('../data/processed/jobs_processed.csv')

print("=== PREPROCESSED DATA OVERVIEW ===")
print(f"Processed {len(processed_resumes_df)} resumes and {len(processed_jobs_df)} jobs")

print("\n--- PROCESSED RESUMES ---")
print(processed_resumes_df.head(3))

print("\n--- PROCESSED JOBS ---")
print(processed_jobs_df.head(3))

print("\n--- DATA COMPARISON ---")
print("Original vs Processed Resume Columns:")
print(f"Original: {list(resumes_df.columns)}")
print(f"Processed: {list(processed_resumes_df.columns)}")

print("\nNew features added:")
print("✓ skills_count, processed flag")
print("✓ experience_range (for jobs)")
print("✓ Normalized text and skills")
# Out:
# === PREPROCESSED DATA OVERVIEW ===
# Processed 10 resumes and 25 jobs
#
# --- PROCESSED RESUMES ---
#             name      role_category                      skills  \
# 0     john smith    devops engineer   ['Docker', 'AWS', 'Java']
# 1  sarah johnson  software engineer  ['Python', 'React', 'SQL']
# 2  sarah johnson  software engineer     ['SQL', 'React', 'AWS']
#
#    experience_years  skills_count  processed
# 0                10             3       True
# 1                 8             3       True
# 2                 7             3       True
#
# --- PROCESSED JOBS ---
#                title     company                       required_skills  \
# 0     data scientist  devcompany  ['Python', 'Docker', 'React', 'SQL']
# 1  software engineer    datasoft      ['SQL', 'AWS', 'Java', 'Docker']
# 2  software engineer  devcompany    ['Java', 'React', 'AWS', 'Python']
#
#    min_experience  max_experience  skills_count  experience_range  processed
# 0               2               9             4                 7       True
# 1               4               5             4                 1       True
# 2               5               5             4                 0       True
#
# --- DATA COMPARISON ---
# Original vs Processed Resume Columns:
# Original: ['name', 'role_category', 'skills', 'experience_years']
# Processed: ['name', 'role_category', 'skills', 'experience_years', 'skills_count', 'processed']
#
# New features added:
# ✓ skills_count, processed flag
# ✓ experience_range (for jobs)
# ✓ Normalized text and skills

# %%
# Add this new cell at the very end

## 7. Step-by-Step Preprocessing Visualization

import pandas as pd

print("=== STEP-BY-STEP PREPROCESSING ===")

# STEP 1: Load original data
print("\n🔸 STEP 1: Original Data")
print("First resume (raw):")
original_resume = resumes_data[0]
print(json.dumps(original_resume, indent=2))

# STEP 2: Text cleaning
print("\n🔸 STEP 2: Text Cleaning")
def show_text_cleaning(text):
    original = text
    cleaned = text.lower().strip()
    print(f"'{original}' → '{cleaned}'")

print("Name cleaning:")
show_text_cleaning(original_resume['name'])
print("Role cleaning:")
show_text_cleaning(original_resume['role_category'])

# STEP 3: Skill normalization
print("\n🔸 STEP 3: Skill Normalization")
original_skills = original_resume['skills']
print(f"Original skills: {original_skills}")

skill_mappings = {
    'sql': 'SQL', 'react': 'React', 'java': 'Java', 
    'python': 'Python', 'aws': 'AWS', 'docker': 'Docker'
}
normalized_skills = [skill_mappings.get(skill.lower(), skill.title()) for skill in original_skills]
print(f"Normalized skills: {normalized_skills}")

# STEP 4: Add new features
print("\n🔸 STEP 4: Feature Engineering")
print(f"Added skills_count: {len(original_skills)}")
print(f"Added processed flag: True")

# STEP 5: Final processed result
print("\n🔸 STEP 5: Final Processed Data")
processed_resumes_df = pd.read_csv('../data/processed/resumes_processed.csv')
print("Processed resume (first row):")
print(processed_resumes_df.iloc[0].to_dict())

print("\n✅ PHASES 2 & 3 COMPLETE!")
print("Ready for Phase 4: Feature Engineering")
# Out:
# === STEP-BY-STEP PREPROCESSING ===
#
# 🔸 STEP 1: Original Data
# First resume (raw):
# {
#   "name": "John Smith",
#   "role_category": "DevOps Engineer",
#   "skills": [
#     "Docker",
#     "AWS",
#     "Java"
#   ],
#   "experience_years": 10
# }
#
# 🔸 STEP 2: Text Cleaning
# Name cleaning:
# 'John Smith' → 'john smith'
# Role cleaning:
# 'DevOps Engineer' → 'devops engineer'
#
# 🔸 STEP 3: Skill Normalization
# Original skills: ['Docker', 'AWS', 'Java']
# Normalized skills: ['Docker', 'AWS', 'Java']
#
# 🔸 STEP 4: Feature Engineering
# Added skills_count: 3
# Added processed flag: True
#
# 🔸 STEP 5: Final Processed Data
# Processed resume (first row):
# {'name': 'john smith', 'role_category': 'devops engineer', 'skills': "['Docker', 'AWS', 'Java']", 'experience_years': 10, 'skills_count': 3, 'processed': True}
#
# ✅ PHASES 2 & 3 COMPLETE!
# Ready for Phase 4: Feature Engineering

# %%
---
# 🎯 PHASE 4: FEATURE ENGINEERING RESULTS
---

## 8. Feature Engineering Analysis

# Load the features created by our pipeline
features_df = pd.read_csv('../data/features/matching_features.csv')

print("=== FEATURE ENGINEERING RESULTS ===")
print(f"Created {len(features_df)} resume-job combinations")
print(f"\nFeature columns:")
print(list(features_df.columns))

# Show sample features
print("\n--- SAMPLE FEATURES ---")
print(features_df.head(3))

# Show top matches
print("\n--- TOP 5 MATCHES ---")
top_matches = features_df.nlargest(5, 'overall_match_score')
for _, match in top_matches.iterrows():
    print(f"{match['resume_name']} → {match['job_title']}: {match['overall_match_score']:.3f}")

print("\n✅ Features ready for ML model!")
